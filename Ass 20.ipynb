# %% [markdown]
# **Q1.** Set the variable test1 to the string &#39;This is a test of the emergency text system,&#39; and save test1 to a
# file named test.txt.
#
# **Q10.** Increment the count field of test and print it.

# %%
import os

test1 = 'This is a test of the emergency text system,'
with open('test.txt','w') as file:
    file.write(test1)

# %% [markdown]
# **Q2.** Read the contents of the file test.txt into the variable test2. Is  here a difference between test 1 and test 2?

# %%
with open('test.txt','r') as file:
    fl= file.read()
    
print(fl)
# Out:
# This is a test of the emergency text system,

# %% [markdown]
# **Q3.** Create a CSV file called books.csv by using these lines:
# title,author,year
#
# The Weirdstone of Brisingamen,Alan Garner,1960
#
# Perdido Street Station,China Miéville,2000
#
# Thud!,Terry Pratchett,2005
#
# The Spellman Files,Lisa Lutz,2007
#
# Small Gods,Terry Pratchett,1992

# %%
books = '''title,author,year
The Weirdstone of Brisingamen,Alan Garner,1960
Perdido Street Station,China Miéville,2000
Thud!,Terry Pratchett,2005
The Spellman Files,Lisa Lutz,2007
Small Gods,Terry Pratchett,1992'''

with open('books.csv','w+') as csvfile:
    csvfile.write(books)
# Out:
# title,author,year
# The Weirdstone of Brisingamen,Alan Garner,1960
# Perdido Street Station,China Miéville,2000
# Thud!,Terry Pratchett,2005
# The Spellman Files,Lisa Lutz,2007
# Small Gods,Terry Pratchett,1992

# %% [markdown]
# **Q4.** Use the sqlite3 module to create a SQLite database called books.db, and a table called books with these fields: title (text), author (text), and year (integer).

# %%
import sqlite3
db = sqlite3.connect('books.db')
cursor = db.cursor()
cursor.execute("CREATE TABLE books (title text, author text, year int)")
db.commit()
db.close()

# %% [markdown]
# **Q5.** Read books.csv and insert its data into the book table.

# %%
import sqlite3
import csv
cont = sqlite3.connect("books.db")
cursor = cont.cursor()
with open("books.csv","r") as file:
    books = csv.DictReader(file)
    for book in books:
        cursor.execute("INSERT INTO books VALUES (?,?,?)",(book['title'],book['author'],book['year']))
cont.commit()
cont.close()

# %% [markdown]
# **Q6.** Select and print the title column from the book table in alphabetical order.

# %%
import sqlite3
cont = sqlite3.connect('books.db')
cursor = cont.cursor()
title = cursor.execute("SELECT title FROM books ORDER BY title")
for i in title:
    print(i[0])
cont.commit()
cont.close()
# Out:
# Perdido Street Station
# Small Gods
# The Spellman Files
# The Weirdstone of Brisingamen
# Thud!

# %% [markdown]
# **Q7.** From the book table, select and print all columns in the order of publication.

# %%
import sqlite3
cont = sqlite3.connect('books.db')
cursor = cont.cursor()
ouput = cursor.execute("SELECT * FROM books ORDER BY year")
for i in ouput:
    print(i)
# Out:
# ('The Weirdstone of Brisingamen', 'Alan Garner', 1960)
# ('Small Gods', 'Terry Pratchett', 1992)
# ('Perdido Street Station', 'China Miéville', 2000)
# ('Thud!', 'Terry Pratchett', 2005)
# ('The Spellman Files', 'Lisa Lutz', 2007)

# %% [markdown]
# **Q8.** Use the sqlalchemy module to connect to the sqlite3 database books.db that you just made in exercise 6.

# %%
import sqlalchemy
cont = sqlalchemy.create_engine('sqlite:///books.db')
cont
# Out:
# Engine(sqlite:///books.db)

# %% [markdown]
# **Q9.** Install the Redis server and the Python redis library (pip install redis) on your computer. Create a Redis hash called test with the fields count (1) and name (&#39;Fester Bestertester&#39;). Print all the fields for
# test.

# %%
pip install redis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting redis
#   Downloading redis-4.4.0-py3-none-any.whl (236 kB)
#      |████████████████████████████████| 236 kB 4.9 MB/s
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.8/dist-packages (from redis) (4.0.2)
# Installing collected packages: redis
# Successfully installed redis-4.4.0

# %%
import redis
cont= redis.Redis()
cont.hset('test', {'count': 1, 'name': 'Fester Bestertester'})
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/redis/connection.py in connect(self)
#     597         try:
# --> 598             sock = self.retry.call_with_retry(
#     599                 lambda: self._connect(), lambda error: self.disconnect(error)
#
# /usr/local/lib/python3.8/dist-packages/redis/retry.py in call_with_retry(self, do, fail)
#      45             try:
# ---> 46                 return do()
#      47             except self._supported_errors as error:
#
# /usr/local/lib/python3.8/dist-packages/redis/connection.py in <lambda>()
#     598             sock = self.retry.call_with_retry(
# --> 599                 lambda: self._connect(), lambda error: self.disconnect(error)
#     600             )
#
# /usr/local/lib/python3.8/dist-packages/redis/connection.py in _connect(self)
#     663         if err is not None:
# --> 664             raise err
#     665         raise OSError("socket.getaddrinfo returned an empty list")
#
# /usr/local/lib/python3.8/dist-packages/redis/connection.py in _connect(self)
#     651                 # connect
# --> 652                 sock.connect(socket_address)
#     653
#
# OSError: [Errno 99] Cannot assign requested address
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-39-9bc6e5a785b6> in <module>
#       1 import redis
#       2 cont= redis.Redis()
# ----> 3 cont.hset('test', {'count': 1, 'name': 'Fester Bestertester'})
#
# /usr/local/lib/python3.8/dist-packages/redis/commands/core.py in hset(self, name, key, value, mapping, items)
#    4857                 items.extend(pair)
#    4858
# -> 4859         return self.execute_command("HSET", name, *items)
#    4860
#    4861     def hsetnx(self, name: str, key: str, value: str) -> Union[Awaitable[bool], bool]:
#
# /usr/local/lib/python3.8/dist-packages/redis/client.py in execute_command(self, *args, **options)
#    1253         pool = self.connection_pool
#    1254         command_name = args[0]
# -> 1255         conn = self.connection or pool.get_connection(command_name, **options)
#    1256
#    1257         try:
#
# /usr/local/lib/python3.8/dist-packages/redis/connection.py in get_connection(self, command_name, *keys, **options)
#    1387         try:
#    1388             # ensure this connection is connected to Redis
# -> 1389             connection.connect()
#    1390             # connections that the pool provides should be ready to send
#    1391             # a command. if not, the connection was either returned to the
#
# /usr/local/lib/python3.8/dist-packages/redis/connection.py in connect(self)
#     602             raise TimeoutError("Timeout connecting to server")
#     603         except OSError as e:
# --> 604             raise ConnectionError(self._error_message(e))
#     605
#     606         self._sock = sock
#
# ConnectionError: Error 99 connecting to localhost:6379. Cannot assign requested address.
