# %% [markdown]
# **Q1.** Write a Python program to print &quot;Hello Python&quot;?

# %%
print('Hello Python')
# Out:
# Hello Python

# %% [markdown]
# **Q2.** Write a Python program to do arithmetical operations addition and division.?

# %%
i= 0
while i<1:
  ch= input('Choose one: addition or division ')
  if ch== '+' or ch== '/':
    num1= int(input('Enter first number: '))
    num2= int(input('Enter second number: '))
    if ch=='+':
      print(num1+num2)
      break
    elif ch=='/':
      print(num1/num2)
      break
  else:
    print('Pleae only choose from + or /')
# Out:
# Choose one: addition or division 53
# Pleae only choose from + or /
# Choose one: addition or division 98
# Pleae only choose from + or /
# Choose one: addition or division +
# Enter first number: 56
# Enter second number: 58
# 114

# %% [markdown]
# **Q3.** Write a Python program to find the area of a triangle?

# %%
h= int(input('Enter height of triangle: '))
b= int(input('Enter base of triangle: '))
area= (h*b)/2
print('Area of the triangle is: ', area)
# Out:
# Enter height of triangle: 10
# Enter base of triangle: 9
# Area of the triangle is:  45.0

# %% [markdown]
# **Q4.** Write a Python program to swap two variables?

# %%
a= int(input('Enter first number: '))
b= int(input('Enter second number: '))
sw= b
b=a
a= sw
print('The numbers are swapes\na:{} b:{}'.format(a,b))
# Out:
# Enter first number: 5
# Enter second number: 10
# The numbers are swapes
# a:10 b:5

# %% [markdown]
# **Q5.** Write a Python program to generate a random number?

# %%
from random import randint

st= int(input('Enter start of the range: '))
ed= int(input('Enter end of the range: '))
print('Random number: ',randint(st,ed))
# Out:
# Enter start of the range: 1
# Enter end of the range: 9999
# Random number:  4556
