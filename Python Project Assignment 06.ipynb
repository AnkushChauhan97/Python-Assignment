# %% [markdown]
# **Q1.** Write a Python Program to Display Fibonacci Sequence Using Recursion?

# %%
fibolist= []
def fibo(n):  
  if n <= 1:  
    return n  
  else:
    return(fibo(n-1) + fibo(n-2)) 
  fibolist.append(n)
  
num = int(input("Enter lenght: "))

print("Fibonacci list is:")  
for i in range(num):  
  fibolist.append(fibo(i))
print(fibolist)
# Out:
# Enter lenght: 9
# Fibonacci list is:
# [0, 1, 1, 2, 3, 5, 8, 13, 21]

# %% [markdown]
# **Q2.** Write a Python Program to Find Factorial of Number Using Recursion?

# %%
def fact(n):
  if n<=1:
    return 1
  else:
    return n*fact(n-1)

num = int(input("Enter number: "))
print('Factorial of {} is: {}'.format(num,fact(num)))
# Out:
# Enter number: 8
# Factorial of 8 is: 40320

# %% [markdown]
# **Q3.** Write a Python Program to calculate your Body Mass Index?

# %%
def bmi(w,h):
  return w/((h/100)**2)

w= int(input('Enter weight in kg: '))
h= int(input('Enter height in cm: '))

status= str
if bmi(w,h)<=18:
  print('Your BMI is: {}, you are underweight.'.format(bmi(w,h)))
elif bmi(w,h)<=27:
  print('Your BMI is: {}, you are normal.'.format(bmi(w,h)))
elif bmi(w,h)<=35:
  print('Your BMI is: {}, you are overweight.'.format(bmi(w,h)))
else:
  print('Your BMI is: {}, you are Obese.'.format(bmi(w,h)))
# Out:
# Enter weight in kg: 78
# Enter height in cm: 158
# Your BMI is: 31.244992789617044, you are overweight.

# %% [markdown]
# **Q4.** Write a Python Program to calculate the natural logarithm of any number?

# %% [markdown]
# **Q5.** Write a Python Program for cube sum of first n natural numbers?

# %%
def cube(n):
  c= 0
  for i in range(1,n+1):
    c= c + (i**3)
  print('Sum= ', c)

num= int(input('Enter a number: '))
cube(num)
# Out:
# Enter a number: 4
# Sum=  100
